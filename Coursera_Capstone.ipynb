# %% [markdown]
# <a href="https://colab.research.google.com/github/kenrp8/Coursera_Capstone/blob/main/Coursera_Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project
# The current notebook will be use to develop the proyect of the course: ```applied data science capston```. This project will be related with spacial data an neighborhood characteristics.

# %%
# import tools
import pandas as pd
import numpy as np

# %%
#Main code
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
